# %%
# %matplotlib notebook

# %reload_ext autoreload
# %autoreload 2

# %%
import pathlib
import numpy as np
import astropy.io.fits

from kgpy.observatories.cds import fdm

# %%
file = pathlib.Path(fdm.__file__).parent / 's15600r00.fits'
hdul = astropy.io.fits.open(file, memmap=True)
# hdul[1].verify('fix')

# %%
hdul[1].header
# Out:
# XTENSION= 'BINTABLE'           /Written by IDL:  Sat May  1 04:34:12 1999
# BITPIX  =                    8 /
# NAXIS   =                    2 /Binary table
# NAXIS1  =              4219560 /Number of bytes per row
# NAXIS2  =                    1 /Number of rows
# PCOUNT  =                    0 /Random parameter count
# GCOUNT  =                    1 /Group count
# TFIELDS =                   29 /Number of columns
# DATE    = '1999-05-01'         /
# SFDUADID= 'NSSD0229'           /SFDU ADID
# FILENAME= 's15600r00.fits'     /
# ORIGIN  = 'SOHO-EOF'           /Institute where file was written
# TELESCOP= 'SOHO    '           /Solar Heliospheric Observatory
# INSTRUME= 'CDS     '           /Coronal Diagnostic Spectrometer
# DETECTOR= 'NIS     '           /Normal or Grazing Incidence Spectrometer
# PROG_NUM=                15600 /Study counter
# PROG_IND=                    1 /Repeated study index
# SEQ_IND =                    0 /Raster index within the study
# ...

# %%
a = hdul[1].data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-c9ad803c7dfa> in <module>
# ----> 1 a = hdul[1].data
#       2
#
# ~\AppData\Roaming\Python\Python37\site-packages\astropy\utils\decorators.py in __get__(self, obj, owner)
#     742                 return val
#     743             else:
# --> 744                 val = self.fget(obj)
#     745                 obj.__dict__[self._key] = val
#     746                 return val
#
# ~\AppData\Roaming\Python\Python37\site-packages\astropy\io\fits\hdu\table.py in data(self)
#     397     @lazyproperty
#     398     def data(self):
# --> 399         data = self._get_tbdata()
#     400         data._coldefs = self.columns
#     401         data._character_as_bytes = self._character_as_bytes
#
# ~\AppData\Roaming\Python\Python37\site-packages\astropy\io\fits\hdu\table.py in _get_tbdata(self)
# ...
